# %% [markdown]
# # <div align='center' style='font-size:30px;color:#336699;'>Image Scaling Attack on Machine Learning Algorithms: A Cyber Security Perspective 💻</div>

# %% [markdown]
# Install required libraries.

# %%
# !pip install tensorflow-constrained-optimization
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install pillow
# Out:
# Requirement already satisfied: tensorflow-constrained-optimization in c:\users\shafqat nawab\anaconda3\lib\site-packages (0.2)
# Requirement already satisfied: numpy in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-constrained-optimization) (1.24.3)
# Requirement already satisfied: scipy in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-constrained-optimization) (1.11.1)
# Requirement already satisfied: six in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-constrained-optimization) (1.16.0)
# Requirement already satisfied: tensorflow>=1.14 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-constrained-optimization) (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow>=1.14->tensorflow-constrained-optimization) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (3.3.0)
# Requirement already satisfied: packaging in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (4.25.2)
# Requirement already satisfied: setuptools in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (68.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.14->tensorflow-constrained-optimization) (3.2.2)
# Requirement already satisfied: opencv-python in c:\users\shafqat nawab\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\shafqat nawab\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\shafqat nawab\anaconda3\lib\site-packages (from opencv-contrib-python) (1.24.3)
# Requirement already satisfied: pillow in c:\users\shafqat nawab\anaconda3\lib\site-packages (9.4.0)

# %% [markdown]
# Import the required libraries.

# %%
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
import tensorflow_constrained_optimization as tfco
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import cv2
import numpy as np
import argparse
from pathlib import Path
import os
import sys
import random
from PIL import Image
from keras.applications.resnet50 import preprocess_input

# %% [markdown]
# ### Functionality and Optimization of Image Scaling Attack

# %%
class Problem(tfco.ConstrainedMinimizationProblem):
    def __init__(self, S, T, method, epsilon):
        self._delta = tf.Variable(tf.expand_dims(tf.ones(shape=S.shape, dtype=tf.float32), axis=0), trainable=True, name="delta")
        self._S = tf.expand_dims(tf.convert_to_tensor(S, dtype=tf.float32) / 255, axis=0)
        self._T = tf.expand_dims(tf.convert_to_tensor(T, dtype=tf.float32) / 255, axis=0)
        self._method = method
        self._epsilon = epsilon
        self._delta_shape = self._S.shape
        self._main_constraint = 0
        self._n_constraints = self._T.shape[0] * self._T.shape[1] * self._T.shape[2] * self._T.shape[3] * 2 + 1

    @property
    def num_constraints(self):
        return self._n_constraints

    def objective(self):
        return tf.norm(self._delta, ord='euclidean')

    def constraints(self):
        D = tf.image.resize(self._S + self._delta, size=[self._T.shape[1], self._T.shape[2]], method=self._method)
        main_contraint = tf.norm((D - self._T), ord='euclidean') - self._epsilon
        self._main_constraint = main_contraint
        main_contraint = tf.reshape(main_contraint, shape=(1,1))
        gt_or_eq_to_zero= tf.reshape(-D, shape=(D.shape[0] * D.shape[1] * D.shape[2] * D.shape[3], 1))
        lt_or_eq_to_1= tf.reshape(D - 1, shape=(D.shape[0] * D.shape[1] * D.shape[2] * D.shape[3], 1))

        constraints = tf.concat([main_contraint, gt_or_eq_to_zero, lt_or_eq_to_1], axis=0)
        constraints = tf.reshape(constraints, shape=(constraints.shape[0]))
        return constraints
        
def optimize(S, T, method, epsilon, iterations):
    problem = Problem(S, T, method, epsilon)
    optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.1)

    for i in range(iterations):
        with tf.GradientTape() as tape:
            loss = problem.objective()
            constraints = problem.constraints()
            
            # Adding a term to the loss for any constraints that are violated.
            loss += tf.reduce_sum(tf.nn.relu(constraints))

        gradients = tape.gradient(loss, [problem._delta])
        optimizer.apply_gradients(zip(gradients, [problem._delta]))

        if i % 1000 == 0:
            print(f'[*] Step = {i}')
            print("\t\t[*] Modification size: ", problem.objective().numpy())
            print("\t\t[*] Difference between the modified image (A) and target image: ", problem._main_constraint.numpy())

    # Modified image
    A = problem._S[0] + problem._delta[0]
    return A

# %% [markdown]
# Select any source image *(S)* and a target image *(T)* for the attack.

# %%
# Source image (S)
source_path = 'C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/pics/70.png'

# Target image (T)
target_path = 'C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/pictures/124124.png'

# %%
def show_image(image_path):
    img = image.load_img(image_path)
    img_tensor = image.img_to_array(img)
    img_tensor /= 255
    plt.imshow(img_tensor)
    print(img_tensor.shape)

# %%
# Source image (S)
show_image(source_path)
# Out:
# (889, 1400, 3)

# %%
# Target image (T)
show_image(target_path)
# Out:
# (54, 54, 3)

# %%
def load_image(tam):
    img = image.load_img(source_path, target_size=(tam, tam))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    return img_tensor

# %% [markdown]
# ### Attack Modes
# * #### Attack mode 1:
#
#      Checks if the test image classifies under the given false classification label.
#
# * #### Attack mode 2:
#
#      Checks if the test image classifies under any label except the given correct classification label.

# %% [markdown]
# ### Attack Execution

# %% [markdown]
# Finds the image size of the ML model for German Traffic Sign Recognition Benchmark (GTSRB), and attempts an image scaling attack to check vulnerable interpolation techniques.

# %%
print("Attacking the model... trying to find out the size of model inputs...\n")

for size in range(1, 2000):
    model = tf.keras.models.load_model('C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/lol.keras')
    image_tensor = load_image(size)

    try:
        preds = model.predict(image_tensor)
    except:
        continue

    break

attack_shape = image_tensor.shape[1:]
print(f"--- The shape of their model inputs is {attack_shape} --- \n")
print("Now checking interpolation method...\n")

S = cv2.cvtColor(cv2.imread(source_path, 1), cv2.COLOR_BGR2RGB)
T = cv2.cvtColor(cv2.imread(target_path, 1), cv2.COLOR_BGR2RGB)
T = cv2.resize(T, (attack_shape[0], attack_shape[1]))

choices = ['bilinear', 'lanczos3', 'lanczos5', 'bicubic', 'gaussian', 'nearest','mitchellcubic']
chosen = []
class_names = {
    0: 'Speed limit (20km/h)',
    1: 'Speed limit (30km/h)',
    2: 'Speed limit (50km/h)',
    3: 'Speed limit (60km/h)',
    4: 'Speed limit (70km/h)',
    5: 'Speed limit (80km/h)',
    6: 'End of speed limit (80km/h)',
    7: 'Speed limit (100km/h)',
    8: 'Speed limit (120km/h)',
    9: 'No passing',
    10: 'No passing veh over 3.5 tons',
    11: 'Right-of-way at intersection',
    12: 'Priority road',
    13: 'Yield',
    14: 'Stop',
    15: 'No vehicles',
    16: 'Veh > 3.5 tons prohibited',
    17: 'No entry',
    18: 'General caution',
    19: 'Dangerous curve left',
    20: 'Dangerous curve right',
    21: 'Double curve',
    22: 'Bumpy road',
    23: 'Slippery road',
    24: 'Road narrows on the right',
    25: 'Road work',
    26: 'Traffic signals',
    27: 'Pedestrians',
    28: 'Children crossing',
    29: 'Bicycles crossing',
    30: 'Beware of ice/snow',
    31: 'Wild animals crossing',
    32: 'End speed + passing limits',
    33: 'Turn right ahead',
    34: 'Turn left ahead',
    35: 'Ahead only',
    36: 'Go straight or right',
    37: 'Go straight or left',
    38: 'Keep right',
    39: 'Keep left',
    40: 'Roundabout mandatory',
    41: 'End of no passing',
    42: 'End no passing veh > 3.5 tons'
}

for choice in choices:
    print(f"CHOICE ---> {choice}\n")
    A = optimize(S, T, choice, 0.1, 4000)
    D = tf.image.resize(tf.expand_dims(A, axis=0), size=[T.shape[0], T.shape[1]])[0]

    D_expanded = np.expand_dims(D, axis=0)
    D_expanded = D_expanded * 255
    D_expanded = D_expanded.astype(np.uint8) / 1

    plt.imshow(D)
    plt.show()

    prediction = model.predict(D_expanded)
    prediction = np.argmax(prediction)

    print()
    print(f"This is a {class_names[prediction]} signal.\n")

    if class_names[prediction] == 'Stop': chosen.append(choice)

    print("-----------------\n")
# Out:
# Attacking the model... trying to find out the size of model inputs...
#
# 1/1 [==============================] - 0s 120ms/step
# --- The shape of their model inputs is (30, 30, 3) ---
#
# Now checking interpolation method...
#
# CHOICE ---> bilinear
#
# [*] Step = 0
# 		[*] Modification size:  1931.7217
# 		[*] Difference between the modified image (A) and target image:  50.3755
# [*] Step = 1000
# 		[*] Modification size:  1614.0558
# 		[*] Difference between the modified image (A) and target image:  0.2512675
# [*] Step = 2000
# 		[*] Modification size:  1298.6553
# 		[*] Difference between the modified image (A) and target image:  3.4175813e-05
# [*] Step = 3000
# 		[*] Modification size:  983.782
# 		[*] Difference between the modified image (A) and target image:  -0.029886216
# 1/1 [==============================] - 0s 24ms/step
#
# This is a Stop signal.
#
# -----------------
#
# CHOICE ---> lanczos3
#
# [*] Step = 0
# 		[*] Modification size:  1931.8304
# 		[*] Difference between the modified image (A) and target image:  50.40986
# [*] Step = 1000
# 		[*] Modification size:  1616.8108
# 		[*] Difference between the modified image (A) and target image:  0.0070875287
# [*] Step = 2000
# 		[*] Modification size:  1301.9933
# 		[*] Difference between the modified image (A) and target image:  0.0126663
# [*] Step = 3000
# 		[*] Modification size:  987.81683
# 		[*] Difference between the modified image (A) and target image:  -0.0078042
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 25ms/step
#
# This is a Stop signal.
#
# -----------------
#
# CHOICE ---> lanczos5
#
# [*] Step = 0
# 		[*] Modification size:  1931.8381
# 		[*] Difference between the modified image (A) and target image:  50.42319
# [*] Step = 1000
# 		[*] Modification size:  1617.0051
# 		[*] Difference between the modified image (A) and target image:  0.0034279525
# [*] Step = 2000
# 		[*] Modification size:  1302.4523
# 		[*] Difference between the modified image (A) and target image:  0.008005619
# [*] Step = 3000
# 		[*] Modification size:  988.6225
# 		[*] Difference between the modified image (A) and target image:  -0.013380997
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 27ms/step
#
# This is a Veh > 3.5 tons prohibited signal.
#
# -----------------
#
# CHOICE ---> bicubic
#
# [*] Step = 0
# 		[*] Modification size:  1931.7966
# 		[*] Difference between the modified image (A) and target image:  50.397934
# [*] Step = 1000
# 		[*] Modification size:  1616.1711
# 		[*] Difference between the modified image (A) and target image:  0.0044180527
# [*] Step = 2000
# 		[*] Modification size:  1300.9491
# 		[*] Difference between the modified image (A) and target image:  -0.010788292
# [*] Step = 3000
# 		[*] Modification size:  986.24396
# 		[*] Difference between the modified image (A) and target image:  -0.01259011
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 25ms/step
#
# This is a Keep left signal.
#
# -----------------
#
# CHOICE ---> gaussian
#
# [*] Step = 0
# 		[*] Modification size:  1931.6802
# 		[*] Difference between the modified image (A) and target image:  50.363567
# [*] Step = 1000
# 		[*] Modification size:  1613.0769
# 		[*] Difference between the modified image (A) and target image:  1.7786561
# [*] Step = 2000
# 		[*] Modification size:  1297.7711
# 		[*] Difference between the modified image (A) and target image:  -0.026571326
# [*] Step = 3000
# 		[*] Modification size:  983.0035
# 		[*] Difference between the modified image (A) and target image:  -0.006373115
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 25ms/step
#
# This is a Go straight or left signal.
#
# -----------------
#
# CHOICE ---> nearest
#
# [*] Step = 0
# 		[*] Modification size:  1931.8655
# 		[*] Difference between the modified image (A) and target image:  50.428684
# [*] Step = 1000
# 		[*] Modification size:  1615.433
# 		[*] Difference between the modified image (A) and target image:  -0.021012627
# [*] Step = 2000
# 		[*] Modification size:  1299.9031
# 		[*] Difference between the modified image (A) and target image:  -0.0118917525
# [*] Step = 3000
# 		[*] Modification size:  984.8373
# 		[*] Difference between the modified image (A) and target image:  0.00062649697
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 24ms/step
#
# This is a Dangerous curve left signal.
#
# -----------------
#
# CHOICE ---> mitchellcubic
#
# [*] Step = 0
# 		[*] Modification size:  1931.7357
# 		[*] Difference between the modified image (A) and target image:  50.381565
# [*] Step = 1000
# 		[*] Modification size:  1614.8353
# 		[*] Difference between the modified image (A) and target image:  -0.0041712224
# [*] Step = 2000
# 		[*] Modification size:  1299.4574
# 		[*] Difference between the modified image (A) and target image:  -0.022969447
# [*] Step = 3000
# 		[*] Modification size:  984.6018
# 		[*] Difference between the modified image (A) and target image:  -0.02123557
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 25ms/step
#
# This is a Stop signal.
#
# -----------------

# %% [markdown]
# ### Vulnerablities

# %%
print(f"The model is vulnerable to size {attack_shape} and methods of interpolation {chosen}")
# Out:
# The model is vulnerable to size (30, 30, 3) and methods of interpolation ['bilinear', 'lanczos3', 'mitchellcubic']

# %% [markdown]
# Effect of quality of the scaled image using different interpolation techniques.

# %%
source_image = cv2.imread('C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/pics/70.png', 1)
target_image = cv2.imread('C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/pictures/124124.png', 1)

methods = [
    cv2.INTER_NEAREST,  # Nearest-neighbor interpolation
    cv2.INTER_LINEAR,   # Bilinear interpolation
    cv2.INTER_CUBIC,    # Bicubic interpolation
    cv2.INTER_AREA,     # Resampling using pixel area relation
    cv2.INTER_LANCZOS4  # Lanczos interpolation over 8x8 pixel neighborhood
]

for method in methods:
    resized_image = cv2.resize(source_image, (target_image.shape[0], target_image.shape[1]), interpolation=method)
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.title(f'Interpolation: {method}')
    plt.axis()
    plt.show()

# %% [markdown]
# ### Defend Mode
# Checks if the test image classifies under the given correct classification label.

# %%
model = load_model('lol.keras')

class_names = {
    0: 'Speed limit (20km/h)',
    1: 'Speed limit (30km/h)',
    2: 'Speed limit (50km/h)',
    3: 'Speed limit (60km/h)',
    4: 'Speed limit (70km/h)',
    5: 'Speed limit (80km/h)',
    6: 'End of speed limit (80km/h)',
    7: 'Speed limit (100km/h)',
    8: 'Speed limit (120km/h)',
    9: 'No passing',
    10: 'No passing veh over 3.5 tons',
    11: 'Right-of-way at intersection',
    12: 'Priority road',
    13: 'Yield',
    14: 'Stop',
    15: 'No vehicles',
    16: 'Veh > 3.5 tons prohibited',
    17: 'No entry',
    18: 'General caution',
    19: 'Dangerous curve left',
    20: 'Dangerous curve right',
    21: 'Double curve',
    22: 'Bumpy road',
    23: 'Slippery road',
    24: 'Road narrows on the right',
    25: 'Road work',
    26: 'Traffic signals',
    27: 'Pedestrians',
    28: 'Children crossing',
    29: 'Bicycles crossing',
    30: 'Beware of ice/snow',
    31: 'Wild animals crossing',
    32: 'End speed + passing limits',
    33: 'Turn right ahead',
    34: 'Turn left ahead',
    35: 'Ahead only',
    36: 'Go straight or right',
    37: 'Go straight or left',
    38: 'Keep right',
    39: 'Keep left',
    40: 'Roundabout mandatory',
    41: 'End of no passing',
    42: 'End no passing veh > 3.5 tons'
}

# Load the test image
source_path = 'C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/pics/70.png'
source_image = cv2.imread(source_path)

# Resize and preprocess the image
input_shape = (30, 30)
resized_image = cv2.resize(source_image, input_shape)
preprocessed_image = resized_image.astype(np.float32) / 255.0
preprocessed_image = np.expand_dims(preprocessed_image, axis=0)

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(cv2.cvtColor(source_image, cv2.COLOR_BGR2RGB))
axes[0].set_title('Original Image')
axes[0].axis('on')

axes[1].imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
axes[1].set_title('Preprocessed Image')
axes[1].axis('on')

plt.show()

defend_prediction = model.predict(preprocessed_image)

# Print probabilities for all classes
print("\nFollowing are the probabilities of each class for the test image: \n")
for idx, prob in enumerate(defend_prediction[0]):
    class_name = class_names.get(idx, "Unknown")
    formatted_prob = "{:.1f}".format(prob)
    print(f"{idx}: '{class_name}' - {formatted_prob}")

# Get the predicted class index with the highest probability
defend_predicted_class_index = np.argmax(defend_prediction)

# Print the predicted class and predicted class name
predicted_class_name = class_names[defend_predicted_class_index]
print(f"\nPredicted class: {defend_predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Check if the predicted class index matches the correct label index
correct_label_index = 4

if defend_predicted_class_index == correct_label_index:
    print("\nDefend mode: Test image classified under the correct classification label.")
else:
    print("\nDefend mode: Test image misclassified.")
# Out:
# 1/1 [==============================] - 0s 122ms/step
#
# Following are the probabilities of each class for the test image:
#
# 0: 'Speed limit (20km/h)' - 0.0
# 1: 'Speed limit (30km/h)' - 0.0
# 2: 'Speed limit (50km/h)' - 0.0
# 3: 'Speed limit (60km/h)' - 0.0
# 4: 'Speed limit (70km/h)' - 0.0
# 5: 'Speed limit (80km/h)' - 0.0
# 6: 'End of speed limit (80km/h)' - 0.0
# 7: 'Speed limit (100km/h)' - 0.0
# 8: 'Speed limit (120km/h)' - 0.0
# 9: 'No passing' - 0.0
# 10: 'No passing veh over 3.5 tons' - 0.0
# 11: 'Right-of-way at intersection' - 0.0
# 12: 'Priority road' - 0.0
# 13: 'Yield' - 0.0
# 14: 'Stop' - 0.0
# 15: 'No vehicles' - 0.0
# 16: 'Veh > 3.5 tons prohibited' - 0.0
# 17: 'No entry' - 0.0
# 18: 'General caution' - 0.0
# 19: 'Dangerous curve left' - 0.0
# 20: 'Dangerous curve right' - 0.0
# 21: 'Double curve' - 0.0
# 22: 'Bumpy road' - 0.0
# 23: 'Slippery road' - 0.0
# 24: 'Road narrows on the right' - 0.0
# 25: 'Road work' - 0.7
# 26: 'Traffic signals' - 0.0
# 27: 'Pedestrians' - 0.0
# 28: 'Children crossing' - 0.0
# 29: 'Bicycles crossing' - 0.0
# 30: 'Beware of ice/snow' - 0.0
# 31: 'Wild animals crossing' - 0.0
# 32: 'End speed + passing limits' - 0.0
# 33: 'Turn right ahead' - 0.0
# 34: 'Turn left ahead' - 0.1
# 35: 'Ahead only' - 0.0
# 36: 'Go straight or right' - 0.0
# 37: 'Go straight or left' - 0.0
# 38: 'Keep right' - 0.0
# 39: 'Keep left' - 0.0
# 40: 'Roundabout mandatory' - 0.1
# 41: 'End of no passing' - 0.0
# 42: 'End no passing veh > 3.5 tons' - 0.0
#
# Predicted class: 25
# Predicted class name: Road work
#
# Defend mode: Test image misclassified.

# %% [markdown]
# ### German Traffic Sign Recognition Benchmark (GTSRB) - Keras Model

# %%
model = tf.keras.models.load_model('C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/lol.keras')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        4640
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  batch_normalization (Batch  (None, 13, 13, 32)        128
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 9, 9, 128)         73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_2 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 43)                22059
#
# =================================================================
# Total params: 1171275 (4.47 MB)
# Trainable params: 1169931 (4.46 MB)
# Non-trainable params: 1344 (5.25 KB)
# _________________________________________________________________

# %% [markdown]
# ### Model evaluation
# Predict random pictures from the model.

# %%
# Function to get a random list of files from a directory
def get_random_files(directory, num_files):
    all_files = os.listdir(directory)
    random_files = random.sample(all_files, num_files)
    return random_files

model = load_model('C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/lol.keras')

class_names = {
    0: 'Speed limit (20km/h)',
    1: 'Speed limit (30km/h)',
    2: 'Speed limit (50km/h)',
    3: 'Speed limit (60km/h)',
    4: 'Speed limit (70km/h)',
    5: 'Speed limit (80km/h)',
    6: 'End of speed limit (80km/h)',
    7: 'Speed limit (100km/h)',
    8: 'Speed limit (120km/h)',
    9: 'No passing',
    10: 'No passing veh over 3.5 tons',
    11: 'Right-of-way at intersection',
    12: 'Priority road',
    13: 'Yield',
    14: 'Stop',
    15: 'No vehicles',
    16: 'Veh > 3.5 tons prohibited',
    17: 'No entry',
    18: 'General caution',
    19: 'Dangerous curve left',
    20: 'Dangerous curve right',
    21: 'Double curve',
    22: 'Bumpy road',
    23: 'Slippery road',
    24: 'Road narrows on the right',
    25: 'Road work',
    26: 'Traffic signals',
    27: 'Pedestrians',
    28: 'Children crossing',
    29: 'Bicycles crossing',
    30: 'Beware of ice/snow',
    31: 'Wild animals crossing',
    32: 'End speed + passing limits',
    33: 'Turn right ahead',
    34: 'Turn left ahead',
    35: 'Ahead only',
    36: 'Go straight or right',
    37: 'Go straight or left',
    38: 'Keep right',
    39: 'Keep left',
    40: 'Roundabout mandatory',
    41: 'End of no passing',
    42: 'End no passing veh > 3.5 tons'
}

test_folder_path = 'C:/Users/shafqat Nawab/Desktop/wania/GTSRB Dataset/Test'
num_random_images = 20

# Get a list of random image file names
random_image_files = get_random_files(test_folder_path, num_random_images)

# Iterate through the randomly selected images
for img_file in random_image_files:
    img_path = os.path.join(test_folder_path, img_file)

    # Load and preprocess the image
    img = Image.open(img_path)
    plt.imshow(img)
    plt.axis('on')
    plt.show()
    img = img.convert('RGB')
    img = img.resize((30, 30))

    # Convert the image to an array and preprocess for prediction
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Make prediction
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    predicted_class_name = class_names.get(predicted_class, "Unknown")

    print(f"Image: {img_file}")
    print(f"Predicted class: {predicted_class}")
    print(f"Predicted class name: {predicted_class_name}")
    print("-" * 40)
# Out:
# 1/1 [==============================] - 0s 152ms/step
# Image: 12050.png
# Predicted class: 16
# Predicted class name: Veh > 3.5 tons prohibited
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 02146.png
# Predicted class: 13
# Predicted class name: Yield
# ----------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# Image: 07759.png
# Predicted class: 13
# Predicted class name: Yield
# ----------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# Image: 10991.png
# Predicted class: 3
# Predicted class name: Speed limit (60km/h)
# ----------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: 06747.png
# Predicted class: 39
# Predicted class name: Keep left
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 09794.png
# Predicted class: 17
# Predicted class name: No entry
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 09443.png
# Predicted class: 29
# Predicted class name: Bicycles crossing
# ----------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# Image: 01307.png
# Predicted class: 17
# Predicted class name: No entry
# ----------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# Image: 04445.png
# Predicted class: 7
# Predicted class name: Speed limit (100km/h)
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 11990.png
# Predicted class: 11
# Predicted class name: Right-of-way at intersection
# ----------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# Image: 05999.png
# Predicted class: 23
# Predicted class name: Slippery road
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: 02554.png
# Predicted class: 9
# Predicted class name: No passing
# ----------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# Image: 03247.png
# Predicted class: 1
# Predicted class name: Speed limit (30km/h)
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 11334.png
# Predicted class: 13
# Predicted class name: Yield
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 00057.png
# Predicted class: 26
# Predicted class name: Traffic signals
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 06473.png
# Predicted class: 15
# Predicted class name: No vehicles
# ----------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# Image: 08053.png
# Predicted class: 38
# Predicted class name: Keep right
# ----------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# Image: 03998.png
# Predicted class: 10
# Predicted class name: No passing veh over 3.5 tons
# ----------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# Image: 03864.png
# Predicted class: 39
# Predicted class name: Keep left
# ----------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Image: 00018.png
# Predicted class: 27
# Predicted class name: Pedestrians
# ----------------------------------------
